# %%
import pandas as pd

# %%
# !ls data/
# Out:
# gender_submission.csv  test.csv  train.csv

# %%
train = pd.read_csv('data/train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv('data/test.csv')

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
test.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
train = pd.get_dummies(train)
test = pd.get_dummies(test)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# 0            1         0       3  22.0      1      0   7.2500           0
# 1            2         1       1  38.0      1      0  71.2833           1
# 2            3         1       3  26.0      0      0   7.9250           1
# 3            4         1       1  35.0      1      0  53.1000           1
# 4            5         0       3  35.0      0      0   8.0500           0
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         1           0           0           1
# 1         0           1           0           0
# 2         0           0           0           1
# 3         0           0           0           1
# 4         1           0           0           1

# %%
test.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0          892       3  34.5      0      0   7.8292           0         1
# 1          893       3  47.0      1      0   7.0000           1         0
# 2          894       2  62.0      0      0   9.6875           0         1
# 3          895       3  27.0      0      0   8.6625           0         1
# 4          896       3  22.0      1      1  12.2875           1         0
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           1           0
# 1           0           0           1
# 2           0           1           0
# 3           0           0           1
# 4           0           0           1

# %%
train['Age'].fillna(train['Age'].mean(), inplace=True)
test['Age'].fillna(test['Age'].mean(), inplace=True)

# %%
test['Fare'].fillna(test['Fare'].mean(), inplace=True)

# %%
X = train.drop('Survived', axis=1)
y = train['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20)

# %%
fit_params={
    "early_stopping_rounds":30, 
    "eval_metric" : 'auc', 
    "eval_set" : [(X_val, y_val)],
    'eval_names': ['valid'],
    'verbose': 100,
    'callbacks': [lgb.reset_parameter(learning_rate=lambda i: np.power(.995, i))],
    'categorical_feature': 'auto'
}

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %%
param_val ={
    'num_leaves': sp_randint(6, 50), 
    'min_child_samples': sp_randint(100, 500), 
    'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
    'subsample': sp_uniform(loc=0.2, scale=0.8), 
    'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
    'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
    'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]
}

# %%
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
clf = lgb.LGBMClassifier(max_depth=-1, silent=True, metric='None',
                         n_jobs=4, n_estimators=5000, min_data=1, min_data_in_bin=1)

# %%
rs = RandomizedSearchCV(
    estimator=clf, 
    param_distributions=param_val, 
    n_iter=100,
    scoring='roc_auc', 
    cv=5,
    refit=True,
)

# %%
X_train.shape
# Out:
# (712, 11)

# %%
X_val.shape
# Out:
# (179, 11)

# %%
rs.fit(X_train, y_train, **fit_params)
print('Best score: {} - Params: {} '.format(rs.best_score_, rs.best_params_))
# Out:
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.787247
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.781916
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.794376
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.802106
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.784515
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.808302
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.793843
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.803105
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.794643
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.796708
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.768857
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.791578
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793577
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.754864
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.789646
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.808236
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.798374
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.815898
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.794376
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.815632
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [21]	valid's auc: 0.800906
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.794909
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.798041
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.806636
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.808702
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.807969
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.809968
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.805637
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.805237
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.8117
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [22]	valid's auc: 0.814832
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.802305
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.81783
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.809768
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.782316
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.791578
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.798841
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.795442
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.804837
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.776453
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.798641
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [28]	valid's auc: 0.800173
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.808169
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.8129
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [21]	valid's auc: 0.823094
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.803971
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.817364
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.799174
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.782716
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.806903
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.735275
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.781383
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.780784
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.704224
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.722215
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.795642
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.796908
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.800906
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.796242
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.773321
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.833089
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.814899
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.797441
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.782716
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.810634
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.769123
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [44]	valid's auc: 0.808502
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.822961
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.797508
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.805704
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.777852
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.794243
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.79391
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.746868
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.794043
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.813433
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.760128
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [35]	valid's auc: 0.807703
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.762127
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [42]	valid's auc: 0.795509
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.820962
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [32]	valid's auc: 0.785848
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.790978
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [38]	valid's auc: 0.791178
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.789845
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [26]	valid's auc: 0.801839
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793577
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.804971
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793577
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.796442
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.810434
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.798241
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.811634
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.810035
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.800373
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.816698
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.809435
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.817764
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.809568
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.818763
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.804171
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.799041
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.799307
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.795776
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.796042
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.798374
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.810501
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.803438
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.794576
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.792111
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.815299
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.803505
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.795509
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.795576
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.809835
# Training until validation scores don't improve for 30 rounds.
# [100]	valid's auc: 0.815165
# Early stopping, best iteration is:
# [82]	valid's auc: 0.820229
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.813166
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.809368
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.815299
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.809102
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.812767
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.808302
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.80697
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.804704
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.81903
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.800373
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [23]	valid's auc: 0.802172
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [19]	valid's auc: 0.796842
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.803372
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.793244
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [18]	valid's auc: 0.799707
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [19]	valid's auc: 0.814033
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [15]	valid's auc: 0.80637
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [29]	valid's auc: 0.806903
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.806237
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.786181
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.789512
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.790179
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.793577
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.789179
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.817164
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.813899
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.815165
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [16]	valid's auc: 0.802439
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [17]	valid's auc: 0.803838
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.806437
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.820229
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.810568
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.792111
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.801972
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.739072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.739072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.739072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.739072
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.732876
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.776053
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.691898
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.746868
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.784248
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.774454
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.820429
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.817297
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.811301
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.816764
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.816764
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.78125
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.789579
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.811567
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.775253
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.774387
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.815432
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.81803
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.812433
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.807769
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.817431
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [11]	valid's auc: 0.820429
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.80677
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.807769
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.804704
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.8117
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.81903
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.808635
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.815032
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.781183
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.804038
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.801839
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.793377
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.790179
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.795709
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.802505
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.814299
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.813699
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.815232
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.804104
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.818497
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.792577
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.794576
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.799707
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [9]	valid's auc: 0.795842
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.795442
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [39]	valid's auc: 0.8129
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.80657
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.821628
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [59]	valid's auc: 0.782783
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.802905
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [14]	valid's auc: 0.799574
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.813433
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.795043
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.804704
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.784715
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.805437
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.787647
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [12]	valid's auc: 0.801306
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [5]	valid's auc: 0.802705
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.812233
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.79451
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.796042
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.791778
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.798241
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.797508
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.788713
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.795776
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.811101
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.815765
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.800706
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [6]	valid's auc: 0.802439
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [32]	valid's auc: 0.821429
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.831557
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [10]	valid's auc: 0.769656
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.821429
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [27]	valid's auc: 0.812233
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.810101
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [16]	valid's auc: 0.803971
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [8]	valid's auc: 0.790112
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.805904
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [24]	valid's auc: 0.847681
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [13]	valid's auc: 0.785181
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [20]	valid's auc: 0.796908
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [25]	valid's auc: 0.774787
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.810634
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.736074
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [1]	valid's auc: 0.5
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [3]	valid's auc: 0.788113
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.806703
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [7]	valid's auc: 0.784915
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.796109
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [2]	valid's auc: 0.787313
# Training until validation scores don't improve for 30 rounds.
# Early stopping, best iteration is:
# [4]	valid's auc: 0.817631
# Best score: 0.8682391280100501 - Params: {'colsample_bytree': 0.9699607033936529, 'min_child_samples': 426, 'min_child_weight': 1, 'num_leaves': 11, 'reg_alpha': 1, 'reg_lambda': 20, 'subsample': 0.33517538499660093}

# %%
opt_parameters = {
    'colsample_bytree': 0.9699607033936529, 
    'min_child_samples': 426, 
    'min_child_weight': 1, 
    'num_leaves': 11, 
    'reg_alpha': 1, 
    'reg_lambda': 20, 
    'subsample': 0.33517538499660093
}

# %%
clf.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         learning_rate=0.1, max_depth=-1, metric='None',
#         min_child_samples=20, min_child_weight=0.001, min_data=1,
#         min_data_in_bin=1, min_split_gain=0.0, n_estimators=5000, n_jobs=4,
#         num_leaves=31, objective=None, random_state=None, reg_alpha=0.0,
#         reg_lambda=0.0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=1)

# %%
submission = pd.DataFrame()
submission['PassengerId'] = test['PassengerId']
submission['Survived'] = clf.predict(test)
# Out:
# /home/pstwh/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
submission.to_csv('submission.csv', index=False)
